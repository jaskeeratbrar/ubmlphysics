# %%
import awkward
import matplotlib.pyplot as plt
import numpy as np

# %%
# line 1 points 
x1 = [35,40,45,50,55,60] 
#y2 = [95.21, 94.52, 95.15, 95.20, 95.01]
y1 = [76.07,76.18,76.94,77.21,77.73,75.25]
# plotting the line 1 points  
plt.plot(x1, y1, label = "Train_Accuracy") 
  
# line 2 points 
x2 = [35,40,45,50,55,60] 
#y2 = [94.83, 94.41, 95.00, 94.84, 94.70] 
y2 = [75.28,75.36,76.15,75.92,76.90,74.41]
# plotting the line 2 points  
plt.plot(x2, y2, label = "Test_Accuracy") 
  
# naming the x axis 
plt.xlabel('Hidden_Nodes') 
# naming the y axis 
plt.ylabel('Accuracy (%)') 
# giving a title to my graph 
plt.title('Lambda X Performance, Constant:Lambda = 15') 
  
# show a legend on the plot 
plt.legend() 
  
# function to show the plot 
plt.show()
