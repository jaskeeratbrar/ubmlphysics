# %%
import awkward
import matplotlib.pyplot as plt
import numpy as np

# %%
# line 1 points 
x1 = [0,5,10,15,20] 
y1 = [95.21, 94.52, 95.15, 95.20, 95.01] 
# plotting the line 1 points  
plt.plot(x1, y1, label = "Train_Accuracy") 
  
# line 2 points 
x2 = [0,5,10,15,20] 
y2 = [94.83, 94.41, 95.00, 94.84, 94.70] 
# plotting the line 2 points  
plt.plot(x2, y2, label = "Test_Accuracy") 
  
# naming the x axis 
plt.xlabel('Lambda') 
# naming the y axis 
plt.ylabel('Accuracy (%)') 
# giving a title to my graph 
plt.title('Lambda X Performance, Constant:Hidden_Node = 50') 
  
# show a legend on the plot 
plt.legend() 
  
# function to show the plot 
plt.show()
